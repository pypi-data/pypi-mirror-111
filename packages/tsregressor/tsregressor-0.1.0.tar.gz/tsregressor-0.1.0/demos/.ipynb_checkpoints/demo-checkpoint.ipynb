# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append('../')
import tsregressor

# %%
df = pd.read_csv('air_passenger.csv',sep=';')
df['date'] = pd.to_datetime(df['date'],format="%d/%m/%Y")

# noisy inputs
df['exog1'] = df['volume'] + np.random.rand(len(df.index))*100
df['exog2'] = df['volume'] ** .5
df['exog3'] = df['volume'] + np.random.rand(len(df.index))*100

print(df.shape)
df.head(2)
# Out:
# (144, 5)
#         date  volume       exog1      exog2       exog3
# 0 1949-01-01     112  189.279868  10.583005  116.877208
# 1 1949-02-01     118  125.063438  10.862780  164.832620

# %%
plt.plot(df['date'],df['volume'])

# %%
plt.plot(df['date'],df['exog3'])

# %%
horizon = 24
test_date = pd.date_range(start=df['date'].min(),periods=len(df.index)-horizon+1,freq=df['date'].dt.freq).max()
df_temp = df.loc[df['date']<test_date]

clf = tsregressor.TSRegressor(horizon=horizon,
                              exog=['exog1','exog2'],
                              target='volume',
                              date=df_temp['date'])
#pred = clf.fit_predict(df,df['volume'])

clf.fit(df_temp,df_temp['volume'])
df_trans = clf.transform(df_temp)
pred = clf.predict(df_trans)

plt.plot(df['date'],df['volume'],label='y')
plt.plot(pred,label='pred')
mae = np.mean(abs(df.loc[df['date']>test_date,'volume'].values - pred.loc[pred.index>test_date].values))
plt.title('forecast MAE={:0.2f}'.format(mae))
plt.legend()
plt.show()
# Out:
# ../tsregressor/models.py:75: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   X_new['week_of_year'] = X_new.index.weekofyear

# %%
df_feat = pd.DataFrame({'feat':clf.feat_cols,'importance':clf.clf.feature_importances_})
df_feat.sort_values('importance').tail(20)
# Out:
#                   feat  importance
# 9          exog1_Lag28    0.003928
# 3         week_of_year    0.004049
# 53  target_trans_Lag24    0.005364
# 32         exog2_Lag27    0.006619
# 23         exog1_Lag42    0.006848
# 59  target_trans_Lag30    0.007872
# 55  target_trans_Lag26    0.009730
# 29         exog2_Lag24    0.009977
# 75  target_trans_Lag46    0.010270
# 66  target_trans_Lag37    0.010667
# 50         exog2_Lag45    0.018671
# 43         exog2_Lag38    0.020152
# 62  target_trans_Lag33    0.020206
# 26         exog1_Lag45    0.020233
# 24         exog1_Lag43    0.020234
# 70  target_trans_Lag41    0.058629
# 57  target_trans_Lag28    0.075708
# 72  target_trans_Lag43    0.080157
# 56  target_trans_Lag27    0.248986
# 5          exog1_Lag24    0.310733
